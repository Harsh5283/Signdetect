# %%
import cv2
import numpy as np
from cvzone.HandTrackingModule import HandDetector
from cvzone.ClassificationModule import Classifier
import math 
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 3
#       1 import cv2
#       2 import numpy as np
# ----> 3 from cvzone.HandTrackingModule import HandDetector
#       4 from cvzone.ClassificationModule import Classifier
#       5 import math
#
# File ~\AppData\Roaming\Python\Python310\site-packages\cvzone\HandTrackingModule.py:10
#       7 import math
#       9 import cv2
# ---> 10 import mediapipe as mp
#      13 class HandDetector:
#      14     """
#      15     Finds Hands using the mediapipe library. Exports the landmarks
#      16     in pixel format. Adds extra functionalities like finding how
#      17     many fingers are up or the distance between two fingers. Also
#      18     provides bounding box info of the hand found.
#      19     """
#
# File c:\Program Files\Python310\lib\site-packages\mediapipe\__init__.py:16
#       1 # Copyright 2019 - 2022 The MediaPipe Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from mediapipe.python import *
# ---> 16 import mediapipe.python.solutions as solutions
#      17 import mediapipe.tasks.python as tasks
#      20 del framework
#
# File c:\Program Files\Python310\lib\site-packages\mediapipe\python\solutions\__init__.py:17
#       1 # Copyright 2020 The MediaPipe Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 """MediaPipe Solutions Python API."""
# ---> 17 import mediapipe.python.solutions.drawing_styles
#      18 import mediapipe.python.solutions.drawing_utils
#      19 import mediapipe.python.solutions.face_detection
#
# File c:\Program Files\Python310\lib\site-packages\mediapipe\python\solutions\drawing_styles.py:20
#      18 from mediapipe.python.solutions import face_mesh_connections
#      19 from mediapipe.python.solutions import hands_connections
# ---> 20 from mediapipe.python.solutions.drawing_utils import DrawingSpec
#      21 from mediapipe.python.solutions.hands import HandLandmark
#      22 from mediapipe.python.solutions.pose import PoseLandmark
#
# File c:\Program Files\Python310\lib\site-packages\mediapipe\python\solutions\drawing_utils.py:21
#      18 from typing import List, Mapping, Optional, Tuple, Union
#      20 import cv2
# ---> 21 import matplotlib.pyplot as plt
#      22 import numpy as np
#      24 from mediapipe.framework.formats import detection_pb2
#
# File c:\Program Files\Python310\lib\site-packages\matplotlib\__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# File c:\Program Files\Python310\lib\site-packages\matplotlib\rcsetup.py:29
#      27 from matplotlib.cbook import ls_mapper
#      28 from matplotlib.colors import Colormap, is_color_like
# ---> 29 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      30 from matplotlib._enums import JoinStyle, CapStyle
#      32 # Don't let the original cycler collide with our validating cycler
#
# File c:\Program Files\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:15
#      12 from functools import lru_cache, partial
#      13 import re
# ---> 15 from pyparsing import (
#      16     Group, Optional, ParseException, Regex, StringEnd, Suppress, ZeroOrMore, one_of)
#      19 _family_punc = r'\\\-:,'
#      20 _family_unescape = partial(re.compile(r'\\(?=[%s])' % _family_punc).sub, '')
#
# ModuleNotFoundError: No module named 'pyparsing'

# %%
cap =cv2.VideoCapture(0)

detector = HandDetector(maxHands=1)
classifier = Classifier("Models/keras_model.h5","Models/labels.txt")
offset = 20
imgSize =300
counter =0
folder = "DATA"
labels =["A","B","C"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 cap =cv2.VideoCapture(0)
# ----> 3 detector = HandDetector(maxHands=1)
#       4 classifier = Classifier("Models/keras_model.h5","Models/labels.txt")
#       5 offset = 20
#
# NameError: name 'HandDetector' is not defined

# %%
while True:
    success , img =cap.read()
    if not success:
        break

    hands , img = detector.findHands(img)

    if hands :

        hand = hands[0]
        x,y,w,h = hand['bbox']

        imgWhite =np.ones((imgSize , imgSize ,3),np.uint8)*255

        # Ensure crop region stays inside the frame
        y1 = max(0, y - offset)
        y2 = min(img.shape[0], y + h + offset)
        x1 = max(0, x - offset)
        x2 = min(img.shape[1], x + w + offset)

        imgCrop = img[y1:y2, x1:x2]

        # Skip if crop is empty
        if imgCrop.size == 0:
            continue


        # imgCropShape =imgCrop.shape

      
        aspectRatio =h/w

        if aspectRatio >1:
            k = imgSize / h
            wCal = math.ceil(k*w)
            imgResize = cv2.resize(imgCrop ,(wCal , imgSize))  
            # imgResizeShape = imgResize.shape
            wGap =math.ceil((imgSize-wCal)/2)
            imgWhite[:, wGap:wCal+wGap] = imgResize
            prediction, index = classifier.getPrediction(imgWhite)
            print(prediction,index)
            cv2.putText(img, labels[index], (x, y - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)



        else:
            k = imgSize / w
            hCal = math.ceil(k*h)
            imgResize = cv2.resize(imgCrop ,( imgSize, hCal)) 
            # imgResizeShape = imgResize.shape
            hGap =math.ceil((imgSize-hCal)/2)
            imgWhite[hGap:hCal+hGap, :] = imgResize

        
        cv2.imshow("ImageCrop",imgCrop)
        cv2.imshow("ImageWhite",imgWhite)

    cv2.imshow("Image", img)
    cv2.waitKey(1)
  
      

    # if cv2.waitKey(1) & 0xFF == ord('q'):
    #     break

# cap.release()
# cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       3 if not success:
#       4     break
# ----> 6 hands , img = detector.findHands(img)
#       8 if hands :
#      10     hand = hands[0]
#
# NameError: name 'detector' is not defined
